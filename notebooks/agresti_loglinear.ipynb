# %% [markdown]
# # Log-linear Models

# %% [markdown]
# This is an example from Agresti: *Categorical Data Analysis*, 2nd edition, 2003.

# %%
import numpy as np
from scipy import stats
import pandas as pd
from statsmodels import datasets
import statsmodels.stats.api as smstats
import statsmodels.stats.contingency_tables as ctab

from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod import families
from statsmodels.genmod.families import links

from numpy.testing import assert_allclose

# %%
from cda_data import df_injury, df_injury_bin
df_injury
# Out:
#    belt location  gender injury  count
# 0    No    Urban  Female     No   7287
# 1    No    Urban  Female    Yes    996
# 2    No    Urban    Male     No  11587
# 3    No    Urban    Male    Yes    759
# 4    No    Rural  Female     No   3246
# 5    No    Rural  Female    Yes    973
# 6    No    Rural    Male     No   6134
# 7    No    Rural    Male    Yes    757
# 8   Yes    Urban  Female     No  10381
# 9   Yes    Urban  Female    Yes    812
# 10  Yes    Urban    Male     No  10969
# 11  Yes    Urban    Male    Yes    380
# 12  Yes    Rural  Female     No   6123
# 13  Yes    Rural  Female    Yes   1084
# 14  Yes    Rural    Male     No   6693
# 15  Yes    Rural    Male    Yes    513

# %%
df_injury_bin['total']  = df_injury_bin['no_inj'] + df_injury_bin['inj']

mod_b = GLM.from_formula('inj + no_inj ~ belt + location + gender', data=df_injury_bin, family=families.Binomial())
res_b = mod_b.fit()
print(res_b.summary())
#resb.wald_test_terms()
print(res_b.fittedvalues * df_injury_bin['total'])   # fitted count
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:      ['inj', 'no_inj']   No. Observations:                    8
# Model:                            GLM   Df Residuals:                        4
# Model Family:                Binomial   Df Model:                            3
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -37.083
# Date:                Sun, 08 Nov 2015   Deviance:                       7.4645
# Time:                        11:32:41   Pearson chi2:                     7.49
# No. Iterations:                     8
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -1.2164      0.026    -45.918      0.000      -1.268      -1.164
# belt[T.Yes]          -0.5448      0.027    -19.982      0.000      -0.598      -0.491
# location[T.Urban]    -0.7581      0.027    -28.105      0.000      -0.811      -0.705
# gender[T.Male]       -0.8171      0.028    -29.551      0.000      -0.871      -0.763
# =====================================================================================
# 0    1009.785980
# 1     713.377948
# 2     964.338174
# 3     797.497898
# 4     834.068333
# 5     389.767738
# 6    1056.807513
# 7     508.356416
# dtype: float64

# %%
mod_main = GLM.from_formula('count ~ injury + belt + location + gender', data=df_injury, family=families.Poisson())
res_main = mod_main.fit()
print(res_main.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  count   No. Observations:                   16
# Model:                            GLM   Df Residuals:                       11
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -1473.1
# Date:                Sun, 08 Nov 2015   Deviance:                       2792.8
# Time:                        11:32:41   Pearson chi2:                 2.76e+03
# No. Iterations:                     9
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             8.4806      0.009    976.679      0.000       8.464       8.498
# injury[T.Yes]        -2.2975      0.013   -173.470      0.000      -2.323      -2.272
# belt[T.Yes]           0.1522      0.008     19.882      0.000       0.137       0.167
# location[T.Urban]     0.5256      0.008     66.565      0.000       0.510       0.541
# gender[T.Male]        0.2013      0.008     26.244      0.000       0.186       0.216
# =====================================================================================

# %% [markdown]
# Copy the original data frame so we can add results.

# %%
df_res_injury = df_injury.copy()

# %%
df_res_injury['fitted_main'] = res_main.fittedvalues
df_res_injury['resid_pearson_main'] = res_main.resid_pearson
df_res_injury
# Out:
#    belt location  gender injury  count   fitted_main  resid_pearson_main
# 0    No    Urban  Female     No   7287   8153.410029           -9.595196
# 1    No    Urban  Female    Yes    996    819.520899            6.164719
# 2    No    Urban    Male     No  11587   9971.318096           16.180039
# 3    No    Urban    Male    Yes    759   1002.243668           -7.683425
# 4    No    Rural  Female     No   3246   4820.353575          -22.675811
# 5    No    Rural  Female    Yes    973    484.506542           22.192638
# 6    No    Rural    Male     No   6134   5895.113659            3.111324
# 7    No    Rural    Male    Yes    757    592.533532            6.756486
# 8   Yes    Urban  Female     No  10381   9493.344706            9.110343
# 9   Yes    Urban  Female    Yes    812    954.201293           -4.603451
# 10  Yes    Urban    Male     No  10969  11610.008515           -5.949049
# 11  Yes    Urban    Male    Yes    380   1166.952794          -23.036794
# 12  Yes    Rural  Female     No   6123   5612.532416            6.813790
# 13  Yes    Rural  Female    Yes   1084    564.130541           21.887920
# 14  Yes    Rural    Male     No   6693   6863.919004           -2.063024
# 15  Yes    Rural    Male    Yes    513    689.910731           -6.735312

# %% [markdown]
# Note that the Pearson chisquare statistic is very large, the residuals are also very large. This simple model of complete independence fits very badly. Let's try all pairwise interactions with injury.

# %%
mod_I2 = GLM.from_formula('count ~ injury + belt + location + gender + injury * (belt + location + gender)', 
                          data=df_injury, family=families.Poisson())
res_I2 = mod_I2.fit()
print(res_I2.summary())
print(res_I2.wald_test_terms())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  count   No. Observations:                   16
# Model:                            GLM   Df Residuals:                        8
# Model Family:                 Poisson   Df Model:                            7
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -608.44
# Date:                Sun, 08 Nov 2015   Deviance:                       1063.4
# Time:                        11:32:41   Pearson chi2:                 1.04e+03
# No. Iterations:                     9
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Intercept                           8.3783      0.009    906.671      0.000       8.360       8.396
# injury[T.Yes]                      -1.3409      0.025    -54.165      0.000      -1.389      -1.292
# belt[T.Yes]                         0.1900      0.008     23.628      0.000       0.174       0.206
# location[T.Urban]                   0.5946      0.008     71.106      0.000       0.578       0.611
# gender[T.Male]                      0.2690      0.008     33.305      0.000       0.253       0.285
# injury[T.Yes]:belt[T.Yes]          -0.4128      0.027    -15.490      0.000      -0.465      -0.361
# injury[T.Yes]:location[T.Urban]    -0.7158      0.027    -26.868      0.000      -0.768      -0.664
# injury[T.Yes]:gender[T.Male]       -0.7418      0.027    -27.285      0.000      -0.795      -0.688
# ===================================================================================================
#                           chi2                   P>chi2  df constraint
# Intercept        822053.169596                      0.0              1
# injury             2933.832983                      0.0              1
# belt                558.263241  2.0064282466295572e-123              1
# location           5056.098391                      0.0              1
# gender             1109.213769   3.283462898242215e-243              1
# injury:belt         239.929939    4.073632601144164e-54              1
# injury:location     721.907997   5.149557215715819e-159              1
# injury:gender       744.469300   6.397066434343722e-164              1

# %%
res_I2.resid_pearson
# Out:
# 0     -6.749071
# 1     -0.391253
# 2     12.463920
# 3      5.203826
# 4    -16.762191
# 5     -4.903691
# 6      5.815796
# 7      1.780041
# 8      8.647473
# 9      0.174986
# 10   -13.528503
# 11    -5.484681
# 12    11.864135
# 13     5.728443
# 14    -2.335031
# 15    -2.302566
# dtype: float64

# %%
mod_I23 = GLM.from_formula('count ~ injury + belt + location + gender + injury * (belt + location + gender) + belt * location * gender', 
                          data=df_injury, family=families.Poisson())
res_I23 = mod_I23.fit()
print(res_I23.summary())
print(res_I23.wald_test_terms())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  count   No. Observations:                   16
# Model:                            GLM   Df Residuals:                        4
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -80.462
# Date:                Sun, 08 Nov 2015   Deviance:                       7.4645
# Time:                        11:32:41   Pearson chi2:                     7.49
# No. Iterations:                     9
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                        8.0878      0.017    488.884      0.000       8.055       8.120
# injury[T.Yes]                                   -1.2164      0.026    -45.918      0.000      -1.268      -1.164
# belt[T.Yes]                                      0.6364      0.020     31.579      0.000       0.597       0.676
# location[T.Urban]                                0.8041      0.020     40.891      0.000       0.766       0.843
# gender[T.Male]                                   0.6271      0.020     30.940      0.000       0.587       0.667
# injury[T.Yes]:belt[T.Yes]                       -0.5448      0.027    -19.982      0.000      -0.598      -0.491
# injury[T.Yes]:location[T.Urban]                 -0.7581      0.027    -28.105      0.000      -0.811      -0.705
# injury[T.Yes]:gender[T.Male]                    -0.8171      0.028    -29.551      0.000      -0.871      -0.763
# belt[T.Yes]:location[T.Urban]                   -0.2827      0.024    -11.584      0.000      -0.331      -0.235
# belt[T.Yes]:gender[T.Male]                      -0.5419      0.026    -20.925      0.000      -0.593      -0.491
# location[T.Urban]:gender[T.Male]                -0.1575      0.024     -6.453      0.000      -0.205      -0.110
# belt[T.Yes]:location[T.Urban]:gender[T.Male]     0.1286      0.032      3.984      0.000       0.065       0.192
# ================================================================================================================
#                                chi2                   P>chi2  df constraint
# Intercept             239007.843164                      0.0              1
# injury                  2108.433327                      0.0              1
# belt                     997.242998   7.137393593425255e-219              1
# location                1672.101201                      0.0              1
# gender                   957.283857   3.462730921776526e-210              1
# injury:belt              399.266255     7.95540288655828e-89              1
# injury:location          789.886472    8.52985561325871e-174              1
# injury:gender            873.248340  6.4181162305511434e-192              1
# belt:location            134.179651    4.990880338053422e-31              1
# belt:gender              437.846907    3.184525493466248e-97              1
# location:gender           41.645319   1.0942709698811192e-10              1
# belt:location:gender      15.869895    6.784946882747994e-05              1

# %%
df_res_injury['fitted_23'] = res_I23.fittedvalues
df_res_injury['resid_pearson_23'] = res_I23.resid_pearson
df_res_injury
# Out:
#    belt location  gender injury  count   fitted_main  resid_pearson_main  \
# 0    No    Urban  Female     No   7287   8153.410029           -9.595196
# 1    No    Urban  Female    Yes    996    819.520899            6.164719
# 2    No    Urban    Male     No  11587   9971.318096           16.180039
# 3    No    Urban    Male    Yes    759   1002.243668           -7.683425
# 4    No    Rural  Female     No   3246   4820.353575          -22.675811
# 5    No    Rural  Female    Yes    973    484.506542           22.192638
# 6    No    Rural    Male     No   6134   5895.113659            3.111324
# 7    No    Rural    Male    Yes    757    592.533532            6.756486
# 8   Yes    Urban  Female     No  10381   9493.344706            9.110343
# 9   Yes    Urban  Female    Yes    812    954.201293           -4.603451
# 10  Yes    Urban    Male     No  10969  11610.008515           -5.949049
# 11  Yes    Urban    Male    Yes    380   1166.952794          -23.036794
# 12  Yes    Rural  Female     No   6123   5612.532416            6.813790
# 13  Yes    Rural  Female    Yes   1084    564.130541           21.887920
# 14  Yes    Rural    Male     No   6693   6863.919004           -2.063024
# 15  Yes    Rural    Male    Yes    513    689.910731           -6.735312
#
#        fitted_23  resid_pearson_23
# 0    7273.214020          0.161650
# 1    1009.785980         -0.433833
# 2   11632.622052         -0.422996
# 3     713.377948          1.708107
# 4    3254.661826         -0.151830
# 5     964.338174          0.278930
# 6    6093.502102          0.518799
# 7     797.497898         -1.434061
# 8   10358.931667          0.216826
# 9     834.068333         -0.764133
# 10  10959.232262          0.093305
# 11    389.767738         -0.494756
# 12   6150.192487         -0.346741
# 13   1056.807513          0.836471
# 14   6697.643584         -0.056740
# 15    508.356416          0.205953

# %% [markdown]
# This model fits well, neither pearson chisquare not likelihood ration test (deviance) rejects the null of this reduced model compared to the saturated model.

# %%
res_I23.pearson_chi2, stats.chi2.sf(res_I23.pearson_chi2, res_I23.df_resid), res_I23.df_resid
# Out:
# (7.4873844103991001, 0.11226687534959638, 4)

# %%
res_I23.deviance, stats.chi2.sf(res_I23.deviance, res_I23.df_resid), res_I23.df_resid
# Out:
# (7.4644796478879982, 0.11328582854544157, 4)

# %% [markdown]
# Following the convention in loglinear analysis with many interaction effects, we can use shortened names for more compact representation.

# %%
data = df_injury.copy()
data.columns = 'B L G I count'.split()

# %%
data.head()
# Out:
#     B      L       G    I  count
# 0  No  Urban  Female   No   7287
# 1  No  Urban  Female  Yes    996
# 2  No  Urban    Male   No  11587
# 3  No  Urban    Male  Yes    759
# 4  No  Rural  Female   No   3246

# %% [markdown]
# As an example for selecting a model we consider the case with all two way interactions

# %%
formula_main = 'count ~ I + B + L + G'
extras = 'I:B I:L I:G B:L B:G L:G'.split()
formula_i = ' + '.join([formula_main] + extras)
mod_i = GLM.from_formula(formula_i, data=data, family=families.Poisson())
res_i = mod_i.fit()

#print(res_i.summary())
print(formula_i)
print()
print(res_i.wald_test_terms())
print()
print('Pchi2 :', res_i.pearson_chi2, stats.chi2.sf(res_i.pearson_chi2, res_i.df_resid), res_i.df_resid)
print('LR :   ', res_i.deviance, stats.chi2.sf(res_i.deviance, res_i.df_resid), res_i.df_resid)

res_2way = res_i   # keep it for later
# Out:
# count ~ I + B + L + G + I:B + I:L + I:G + B:L + B:G + L:G
#
#                     chi2                   P>chi2  df constraint
# Intercept  311961.089210                      0.0              1
# I            2145.568380                      0.0              1
# B            1321.968147  1.9022425926898486e-289              1
# L            2246.623623                      0.0              1
# G            1273.918864   5.260928393403346e-279              1
# I:B           394.361763    9.296714759053296e-88              1
# I:L           784.941477  1.0141303841740594e-172              1
# I:G           868.648228   6.418793265630765e-191              1
# B:L           169.499128      9.5183764068419e-39              1
# B:G           860.136979   4.547585580362106e-189              1
# L:G            27.502599   1.5688353093521218e-07              1
#
# Pchi2 : 23.3751747251 0.000286130844498 5
# LR :    23.3509914801 0.000289198958995 5

# %%
#print(res_i.summary())

# %% [markdown]
# Next we consider the model with all three-way interactions. All terms are significant, the Pearson chisquare and the LR test do not reject the restricted model compared to the saturated model.

# %%
formula_main = 'count ~ I + B + L + G'
extras = 'G:I:L G:I:B G:L:B I:L:B'.split()
formula_i = ' + '.join([formula_main] + extras)
mod_i = GLM.from_formula(formula_i, data=data, family=families.Poisson())
res_i = mod_i.fit()

#print(res_i.summary())
print(formula_i)
print()
print(res_i.wald_test_terms())
print()
print('Pchi2 :', res_i.pearson_chi2, stats.chi2.sf(res_i.pearson_chi2, res_i.df_resid), res_i.df_resid)
print('LR :   ', res_i.deviance, stats.chi2.sf(res_i.deviance, res_i.df_resid), res_i.df_resid)
# Out:
# count ~ I + B + L + G + G:I:L + G:I:B + G:L:B + I:L:B
#
#                     chi2                   P>chi2  df constraint
# Intercept  218359.717682                      0.0              1
# I            1235.529011  1.1586358583887307e-270              1
# B             875.434584   2.148468125663772e-192              1
# L            1507.832318                      0.0              1
# G             880.968635  1.3460454065168668e-193              1
# G:I:L         845.773244   9.330894597656451e-182              4
# G:I:B         532.907338   3.521441388017188e-115              3
# G:L:B         151.750171   1.1165265528989986e-33              2
# I:L:B           2.235033        0.134913776002798              1
#
# Pchi2 : 1.32461754639 0.249765023856 1
# LR :    1.32531671262 0.249640091476 1

# %% [markdown]
# Agresti reports the deviance and associated LR pvalues in Table 8.1 for the 4 models above and several additional models. The only two models that are acceptable based on the Pearson chisquare and likelihood ratio tests are the model with all three-way interactions and the model with all two-way interactions with injury and three way interaction for non-injury variables. The former has only one residual degree of freedom, the latter has 4

# %% [markdown]
# The Binomial model has a corresponding loglinear model that produces identical effects of the explanatory variables on the *endogenous* variable

# %%
pI23 = res_I23.params[[i for i in res_I23.params.index if 'injury[T.Yes]:' in i]]

# %%
pbinom = res_b.params[1:]

# %%
print(pI23.values)
print(pbinom.values)
# Out:
# [-0.54482918 -0.75805826 -0.81709743]
# [-0.54482918 -0.75805826 -0.81709743]

# %%
pI23
# Out:
# injury[T.Yes]:belt[T.Yes]         -0.544829
# injury[T.Yes]:location[T.Urban]   -0.758058
# injury[T.Yes]:gender[T.Male]      -0.817097
# dtype: float64

# %%
pbinom
# Out:
# belt[T.Yes]         -0.544829
# location[T.Urban]   -0.758058
# gender[T.Male]      -0.817097
# dtype: float64

# %% [markdown]
# The fit statistics, Pearson chisquare and deviance are also identical in the two models, up to numerical precision.

# %%
res_I23.deviance, res_b.deviance
# Out:
# (7.4644796478879982, 7.4644796463436576)

# %%
res_I23.pearson_chi2, res_b.pearson_chi2
# Out:
# (7.4873844103991001, 7.4873844103989455)

# %%
print(np.exp(pbinom))
print('location[T.Rural]', np.exp(-pbinom['location[T.Urban]']))
# Out:
# belt[T.Yes]          0.579941
# location[T.Urban]    0.468575
# gender[T.Male]       0.441712
# dtype: float64
# location[T.Rural] 2.13412827098

# %%
from statsmodels.genmod._prediction import params_transform_univariate
rates = params_transform_univariate(res_b.params, res_b.cov_params())

# %%
print(rates.summary_frame())
# Out:
#                        mean   mean_se  mean_ci_lower  mean_ci_upper
# Intercept          0.296294  0.007849       0.281303       0.312085
# belt[T.Yes]        0.579941  0.015813       0.549762       0.611777
# location[T.Urban]  0.468575  0.012639       0.444448       0.494013
# gender[T.Male]     0.441712  0.012214       0.418411       0.466311

# %%
params_transform_univariate(res_b.params, res_b.cov_params(), link=links.log()).summary_frame()
# Out:
#                        mean   mean_se  mean_ci_lower  mean_ci_upper
# Intercept          0.296294  0.007849       0.281303       0.312085
# belt[T.Yes]        0.579941  0.015813       0.549762       0.611777
# location[T.Urban]  0.468575  0.012639       0.444448       0.494013
# gender[T.Male]     0.441712  0.012214       0.418411       0.466311

# %% [markdown]
# The are poisson intensities, `exp(params)`, which are multiplicative for the predicted intensity, i.e. the predicted mean.
# Agresti calculates several odds_ratio based on either this or the prediction for individual cells.

# %%
params_transform_univariate(res_I23.params, res_I23.cov_params(), link=links.log()).summary_frame()
# Out:
#                                                      mean    mean_se  \
# Intercept                                     3254.661826  53.843408
# injury[T.Yes]                                    0.296294   0.007849
# belt[T.Yes]                                      1.889656   0.038081
# location[T.Urban]                                2.234707   0.043945
# gender[T.Male]                                   1.872238   0.037949
# injury[T.Yes]:belt[T.Yes]                        0.579941   0.015813
# injury[T.Yes]:location[T.Urban]                  0.468575   0.012639
# injury[T.Yes]:gender[T.Male]                     0.441712   0.012214
# belt[T.Yes]:location[T.Urban]                    0.753713   0.018397
# belt[T.Yes]:gender[T.Male]                       0.581664   0.015063
# location[T.Urban]:gender[T.Male]                 0.854260   0.020852
# belt[T.Yes]:location[T.Urban]:gender[T.Male]     1.137213   0.036705
#
#                                               mean_ci_lower  mean_ci_upper
# Intercept                                       3150.823246    3361.922513
# injury[T.Yes]                                      0.281303       0.312085
# belt[T.Yes]                                        1.816474       1.965788
# location[T.Urban]                                  2.150216       2.322518
# gender[T.Male]                                     1.799317       1.948114
# injury[T.Yes]:belt[T.Yes]                          0.549762       0.611777
# injury[T.Yes]:location[T.Urban]                    0.444448       0.494013
# injury[T.Yes]:gender[T.Male]                       0.418411       0.466311
# belt[T.Yes]:location[T.Urban]                      0.718503       0.790647
# belt[T.Yes]:gender[T.Male]                         0.552879       0.611948
# location[T.Urban]:gender[T.Male]                   0.814354       0.896122
# belt[T.Yes]:location[T.Urban]:gender[T.Male]       1.067500       1.211478

# %%
3254.661826 * 0.296294
# Out:
# 964.336771072844

# %%
res_I23.get_prediction().summary_frame()
# Out:
#             mean     mean_se  mean_ci_lower  mean_ci_upper
# 0    7273.214020   83.046621    7112.253432    7437.817378
# 1    1009.785980   25.165716     961.647342    1060.334368
# 2   11632.622052  106.279027   11426.172925   11842.801319
# 3     713.377948   19.390395     676.368058     752.412967
# 4    3254.661826   53.843408    3150.823246    3361.922513
# 5     964.338174   24.673649     917.171254    1013.930723
# 6    6093.502102   75.858527    5946.621336    6244.010804
# 7     797.497898   21.412891     756.614583     840.590323
# 8   10358.931667   99.985997   10164.804738   10556.766022
# 9     834.068333   21.733299     792.541285     877.771288
# 10  10959.232262  103.538480   10758.167866   11164.054444
# 11    389.767738   12.278126     366.430888     414.590840
# 12   6150.192487   75.966606    6003.088502    6300.901214
# 13   1056.807513   26.029603    1007.002267    1109.076072
# 14   6697.643584   80.116004    6542.445499    6856.523235
# 15    508.356416   15.142223     479.527906     538.918054

# %%
res_I23.get_prediction(offset=[-1]).summary_frame()
# Out:
#            mean    mean_se  mean_ci_lower  mean_ci_upper
# 0   2675.665909  30.551145    2616.451818    2736.220101
# 1    371.479502   9.257950     353.770287     390.075215
# 2   4279.402500  39.097869    4203.454111    4356.723131
# 3    262.437081   7.133328     248.821903     276.797262
# 4   1197.323174  19.807883    1159.123095    1236.782175
# 5    354.760188   9.076928     337.408448     373.004268
# 6   2241.674148  27.906793    2187.639734    2297.043205
# 7    293.383081   7.877363     278.342950     309.235898
# 8   3810.837993  36.782793    3739.422686    3883.617185
# 9    306.836592   7.995234     291.559645     322.914011
# 10  4031.676240  38.089678    3957.708782    4107.026110
# 11   143.387538   4.516870     134.802390     152.519447
# 12  2262.529375  27.946553    2208.412843    2317.972018
# 13   388.777757   9.575756     370.455431     408.006286
# 14  2463.925379  29.473031    2406.831194    2522.373936
# 15   187.013874   5.570513     176.408458     198.256872

# %%
params_transform_univariate(res_2way.params, res_2way.cov_params(), link=links.log()).summary_frame()
# Out:
#                              mean    mean_se  mean_ci_lower  mean_ci_upper
# Intercept             3353.829440  48.745240    3259.638480    3450.742154
# I[T.Yes]                 0.294823   0.007774       0.279973       0.310460
# B[T.Yes]                 1.802509   0.029209       1.746160       1.860676
# L[T.Urban]               2.136772   0.034230       2.070725       2.204925
# G[T.Male]                1.784674   0.028963       1.728801       1.842353
# I[T.Yes]:B[T.Yes]        0.582440   0.015853       0.552183       0.614356
# I[T.Yes]:L[T.Urban]      0.469999   0.012666       0.445818       0.495491
# I[T.Yes]:G[T.Male]       0.443084   0.012237       0.419737       0.467730
# B[T.Yes]:L[T.Urban]      0.810648   0.013071       0.785430       0.836675
# B[T.Yes]:G[T.Male]       0.631331   0.009901       0.612222       0.651037
# L[T.Urban]:G[T.Male]     0.918581   0.014875       0.889883       0.948203

# %% [markdown]
# Agresti uses "Urban" as reference level for the locatation. We can replicate by changing the sign of the affected parameters, instead of recoding the model. (This works in this case because we only have two levels, i.e. location is binary, and our transformation is the exponential function.)

# %%
sign_correction = np.ones(len(res_2way.params))
sign_correction[[3, 6, 8]] = -1
params_transform_univariate(sign_correction * res_2way.params, res_2way.cov_params(), link=links.log()).summary_frame()
# Out:
#                              mean    mean_se  mean_ci_lower  mean_ci_upper
# Intercept             3353.829440  48.745240    3259.638480    3450.742154
# I[T.Yes]                 0.294823   0.007774       0.279973       0.310460
# B[T.Yes]                 1.802509   0.029209       1.746160       1.860676
# L[T.Urban]               0.467996   0.007497       0.453530       0.482923
# G[T.Male]                1.784674   0.028963       1.728801       1.842353
# I[T.Yes]:B[T.Yes]        0.582440   0.015853       0.552183       0.614356
# I[T.Yes]:L[T.Urban]      2.127665   0.057338       2.018200       2.243068
# I[T.Yes]:G[T.Male]       0.443084   0.012237       0.419737       0.467730
# B[T.Yes]:L[T.Urban]      1.233581   0.019890       1.195207       1.273188
# B[T.Yes]:G[T.Male]       0.631331   0.009901       0.612222       0.651037
# L[T.Urban]:G[T.Male]     0.918581   0.014875       0.889883       0.948203

# %% [markdown]
# The values for the interaction effects above are the odds ratio as reported in Agresti table 8.10 for the all two-ways model,
# `0.58, 2.13, 0.44, 1.23, 0.63, 1.09`.
#
# Calculating the odds ratio for the previous model with a three-way interaction is more complex and not done here.
